# %%
# %matplotlib notebook
import IPython.display
from utils_demo import *
from sys import platform
import sys
from PIL import Image
import matplotlib.pyplot as plt
import json
import rdflib
import glob
import os
import re
import copy
import time

sys.path.append('../simulation')
sys.path.append('../dataset_utils/')

import numpy as np
import random
import cv2
import add_preconds
import evolving_graph.check_programs as check_programs
import evolving_graph.utils as utils

from unity_simulator.comm_unity import UnityCommunication

# %%
comm = UnityCommunication()

# %%
scene = 2
scene_graph = "TrimmedTestScene" + str(scene) + "_graph"
executable_program_path = "../dataset/programs_processed_precond_nograb_morepreconds/executable_programs/" + scene_graph + "/*/*.txt"
executable_program_list = []
for file_path in glob.glob(executable_program_path):
    executable_program_list.append(file_path.replace("../dataset/programs_processed_precond_nograb_morepreconds/executable_programs/" + scene_graph + "/", ""))

# %%
rdf_g = rdflib.Graph()
rdf_g.parse("../ontology/vh2kg_ontology.ttl", format="ttl")
# Out:
# <Graph identifier=N63cf814adea4423789014d194c6dec9e (<class 'rdflib.graph.Graph'>)>

# %%
def get_activity_from_ontology(activity_type):
    results = []
    qres = rdf_g.query(
    """
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX : <http://www.owl-ontologies.com/VirtualHome.owl#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
select ?activity where { 
    # ?activity rdfs:subClassOf :%s .
 } 
       """ % activity_type)

    result = ""
    for row in qres:
        activity = "".join(row).replace("http://www.owl-ontologies.com/VirtualHome.owl#","")
        arr = activity.split("_")
        arr[0] = arr[0].capitalize()
        activity = " ".join(arr)
        result = activity
        results.append(result)
    return results

# %%
# set character
program_list = []
comm.reset(scene-1)
comm.add_character('chars/Female2')
# Out:
# True

# %%
# load environment
success, g = comm.environment_graph();

# %%
#nodes = g["nodes"]
#edges = g["edges"]
#max_id = nodes[len(nodes)-1]["id"]

# %%
def generate_list_of_steps(file_path):
    file = open(file_path, "r", encoding="utf-8")
    i = 0
    list_of_steps = []
    program_name = ""
    description = ""
    char= "<char0>"
    while True:
        line = file.readline()
        if line:
            line = line.replace("\n","")
            if i==0:
                program_name = line
            elif i==1:
                description = line
            elif line.startswith("["):
                list_of_steps.append(line)
            else:
                pass
            i+=1
        else:
            break
    return program_name, description, list_of_steps

# %%
data_path = "../dataset/programs_processed_precond_nograb_morepreconds/withoutconds/*/*.txt"
program_list = []
for file_path in glob.glob(data_path):
    file_name = file_path.replace("../dataset/programs_processed_precond_nograb_morepreconds/withoutconds/", "")
    if file_name in executable_program_list:
        program_name, description, list_of_steps = generate_list_of_steps(file_path)
        program_list.append({
            "file_name":file_name,
            "name": program_name,
            "description": description,
            "list_of_steps": list_of_steps
        })

# %%
def get_activity_program(category):
    #unexecutable = ["Take shower", "Take shoes off", "Wash teeth", "Wash face", "Dust", "Clean toilet", "Clean room", "Scrubbing living room tile floor is once week activity for me", "Clean mirror", "Play games", "Play on laptop", "Read on sofa"]
    unexecutable = []
    executable = []
    activities = get_activity_from_ontology(category)
    for activity_name in activities:
        if activity_name in unexecutable:
            continue
        results = [program for program in program_list if program["name"] == activity_name]
        if len(results) == 0:
            print("Nothing: " + activity_name)
        else:
            print("Success: " + activity_name)
            executable.append({"activity_name": activity_name, "results": results})
    return executable

# %%
def delete2000(graph_state_list):
    new_graph_state_list = []
    for graph_state in graph_state_list:
        new_nodes = [x for x in graph_state["nodes"] if x["id"] < 2000]
        new_edges = [x for x in graph_state["edges"] if x["from_id"] < 2000 and x["to_id"] < 2000]
        new_graph_state_list.append({"nodes": new_nodes, "edges": new_edges})
    return new_graph_state_list

# %%
def export(activity_name, graph_state_list, activity_cnt):
    os.mkdir("graph_state_list/scene" + str(scene) + "/" + activity_name + "/" + activity_cnt)
    state_cnt = 0
    for graph_state in graph_state_list:
        state_cnt += 1
        file_path = "graph_state_list/scene" + str(scene) + "/"  + activity_name + "/" + activity_cnt + "/activityList-graph-state-" + '{0:03d}'.format(state_cnt) + ".json"
        with open(file_path, 'w') as outfile:
            json.dump(graph_state, outfile)

    with open("graph_state_list/scene" + str(scene) + "/" + activity_name + "/" + activity_cnt + "/activityList-program.txt", 'w') as f:
        for s in executed_program:
            f.write("%s\n" % s)

    with open("graph_state_list/scene" + str(scene) + "/" + activity_name + "/" + activity_cnt + "/program-description.txt", 'w') as f:
        f.write("%s\n" % activity["name"])
        f.write("%s\n" % activity["description"])

# %%
executable_activity_list = []
for activity_class in ["BedTimeSleep", "EatingDrinking", "FoodPreparation", "GettingReady", "HouseArrangement", "HouseCleaning", "HygieneStyling", "Leisure", "Other", "PhysicalActivity", "SocialInteraction", "Work"]:
    executable_activity_list.extend(get_activity_program(activity_class))
# Out:
# Nothing: Bed time
# Nothing: Get ready for bed
# Nothing: Go to bed
# Success: Go to sleep
# Success: Put alarm clock in bedroom
# Nothing: Put them to sleep
# Nothing: Read them bedtime story
# Success: Sleep
# Success: Take nap
# Nothing: Wake me up
# Success: Drink
# Success: Eat
# Nothing: Dance for table as we eat
# Nothing: Dining
# Nothing: Eat breaksfast
# Nothing: Eat cereal
# Nothing: Eat cheese
# Nothing: Eat dessert
# Success: Eat dinner
# Nothing: Eat donuts
# Nothing: Eat family meals
# Nothing: Eat ice cream
# Nothing: Eat meals
# Nothing: Eat on fancy china
# Success: Eat snacks and drink tea
# Nothing: Eat while watching tv
# Success: Get something to drink
# Nothing: Have dinner
# Nothing: Have ice coffee
# Nothing: Have snack
# Nothing: Bake
# Success: Breakfast
# Nothing: Brew coffee
# Success: Chop vegetables
# Success: Cook some food
# Success: Cut bread
# Nothing: Cut steak
# Nothing: Defrost chicken
# Nothing: Eat breakfast
# Nothing: Fix bowl of cereal
# Nothing: Fix sandwhich
# Nothing: Fix sandwich
# Success: Fix snack
# Nothing: Keep an eye on stove as something is cooking
# Nothing: Make  cookies
# Nothing: Make banana bread
# Nothing: Make cereal
# Success: Make coffee
# Nothing: Make drink
# Nothing: Make eggs
# Nothing: Make ice in ice trays for freezer
# Nothing: Make iced coffee
# Nothing: Make jello
# Nothing: Make peanut butter sandwhich
# Nothing: Make peanut butter sandwich
# Success: Make popcorn
# Nothing: Make sandwich
# Nothing: Make sandwitch
# Nothing: Make tea
# Nothing: Make toast
# Nothing: Make tomato sauce
# Nothing: Peel kiwi
# Nothing: Peel potatoes
# Nothing: Prepare breakfast
# Nothing: Prepare dinner
# Nothing: Prepare pot of boiling water
# Nothing: Prepare sandwich
# Nothing: Prepare sandwitch
# Nothing: Slice apple
# Nothing: Squeeze lemon
# Nothing: Toast bread
# Success: Get ready for day
# Nothing: Get ready for school
# Nothing: Get ready for work
# Nothing: Get ready to leave
# Success: Take off outerwear
# Nothing: Added meat to freezer
# Nothing: Arrange bookshelf
# Success: Arrange folders
# Nothing: Arrange furniture
# Nothing: Arrange shoes
# Nothing: Arrange sofa
# Success: Bring dirty plate to sink
# Nothing: Bring leftovers in kitchen
# Nothing: Care for houseplants
# Nothing: Change bedding
# Nothing: Change curtains
# Success: Change light
# Nothing: Change lightbulb
# Nothing: Change sheets and pillow cases
# Nothing: Change sheets on bed
# Nothing: Change shower curtain
# Success: Change toilet paper roll
# Nothing: Change toothbrush
# Success: Clean dishes
# Nothing: Clean glasses
# Nothing: Clear table
# Nothing: Close shower curtain
# Success: Collect napkin rings
# Nothing: Decorate
# Success: Decorate it
# Nothing: Do dishes
# Success: Do laundry
# Success: Empty dishwasher and fill dishwasher
# Nothing: Fluff pillow
# Nothing: Fold laundry
# Nothing: Hang pictures
# Nothing: Hang up poster
# Nothing: Hold coats and umbrellas
# Success: Iron shirt
# Nothing: Lay tablecloth
# Nothing: Light candles
# Success: Load dishwasher
# Success: Make bed
# Nothing: Make childs bed
# Nothing: Make kids bed
# Nothing: Make up bed for guest on couch
# Nothing: Organize cabinet
# Nothing: Organize desk
# Nothing: Organize panrty
# Success: Paint ceiling
# Nothing: Pick toys
# Nothing: Pick up dIshes
# Success: Pick up dirty dishes
# Nothing: Place bathmat
# Success: Place centerpiece
# Nothing: Place table
# Nothing: Polish teas pot
# Nothing: Polish your shoes
# Success: Push all chairs in
# Nothing: Put away clean clothes
# Nothing: Put away dishes
# Success: Put away groceries
# Nothing: Put dishes away
# Nothing: Put down decoration
# Nothing: Put dvds on shelves
# Nothing: Put groceries in fridge
# Nothing: Put mail away
# Success: Put mail in mail organizer
# Nothing: Put new books in shelves
# Success: Put shoes in shoe rack
# Nothing: Put slippers in closet
# Success: Put toys away
# Nothing: Put washed clothes in almirah
# Nothing: Re arrange office
# Nothing: Rearrange photo frames
# Nothing: Replace toothpaste
# Success: Rotate stock in refrigerator
# Nothing: Set up buffet area
# Success: Set up table
# Nothing: Sort clothing and care for it
# Success: Sort laundry
# Nothing: Straighten magazines
# Success: Straighten paintings on wall
# Success: Straighten pictures on wall
# Success: Take dishes out of dishwasher
# Success: Turn night light on
# Success: Turn off light
# Success: Unload dishwasher
# Nothing: Unload various items from pockets and place them in bowl on table
# Nothing: Wash and clean all crystal in china cabinet
# Success: Wash clothes
# Success: Wash dishes
# Success: Wash dishes by hand
# Success: Wash dishes with dishwasher
# Nothing: Water plants
# Success: Vacuum
# Success: Clean
# Success: Clean bathroom
# Success: Clean floor
# Nothing: Clean fridge
# Nothing: Clean kitchen
# Nothing: Clean large jacuzzi tub
# Success: Clean mirror
# Success: Clean room
# Success: Clean screen
# Success: Clean sink
# Success: Clean toilet
# Success: De-wrinkle sheet
# Success: Dust
# Nothing: Fluff pillows
# Nothing: Flush toilet
# Nothing: Mop
# Nothing: Mop floor
# Nothing: Oil dining room
# Nothing: Organize closet
# Nothing: Pick up cat hair
# Nothing: Polish table
# Nothing: Polishing floor
# Nothing: Pull hair out of drain
# Nothing: Scrub toilet
# Success: Scrubbing living room tile floor is once week activity for me
# Nothing: Shred receipts
# Nothing: Sort and fold laundry
# Nothing: Steam mop floor
# Nothing: Sweep and wipe table off with rag
# Nothing: Sweep entrance hall
# Nothing: Sweep floor
# Nothing: Sweep hallway please
# Nothing: Vacuum carpet
# Nothing: Wash dirty dishes
# Success: Wash monitor
# Nothing: Wash sink
# Nothing: Wash table
# Success: Wipe down sink
# Nothing: Wipe room down with lysol
# Success: Shave
# Nothing: Apply lotion
# Nothing: Bathe
# Nothing: Blow dry hair
# Nothing: Broom
# Nothing: Brush hair
# Success: Brush teeth
# Success: Change clothes
# Nothing: Check appearance in mirror
# Nothing: Check self in mirror
# Nothing: Comb hair
# Nothing: Curled hair
# Nothing: Cut toenails
# Nothing: Cut your hair
# Success: Deficate
# Nothing: Do facial
# Nothing: Do nails
# Nothing: Dress up and pretend
# Nothing: Dry hair
# Nothing: Face washing
# Success: Get dressed
# Nothing: Getting dressed
# Nothing: Give children bath
# Nothing: Give me bath
# Nothing: Give your child bath
# Nothing: Go pee
# Nothing: Go to bathroom
# Success: Go to toilet
# Nothing: Hair dressing
# Success: Hand washing
# Nothing: Paint nails
# Nothing: Pee
# Success: Put on coat
# Success: Put on coat and shoes
# Nothing: Put on foundation
# Nothing: Put on glasses
# Nothing: Put on your shoes
# Nothing: Put shoes and coats
# Nothing: Put up coat
# Nothing: Scrub bottom of feet
# Nothing: Scrub face
# Nothing: Shampoo hair
# Nothing: Style hair
# Nothing: Take bath
# Nothing: Take jacket off
# Success: Take off coat
# Success: Take off shoes
# Nothing: Take off shoes and hang up coat
# Success: Take shoes off
# Success: Take shower
# Success: Tale off shoes
# Nothing: Toilet
# Nothing: Use bathroom
# Nothing: Use restroom
# Nothing: Use toilet
# Success: Wash face
# Nothing: Wash hair
# Success: Wash hands
# Success: Wash teeth
# Nothing: Wipe feet
# Nothing: Dance
# Nothing: Play
# Success: Browse computer
# Success: Browse internet
# Nothing: Change tv channels
# Nothing: Eat while watching tv
# Nothing: In living room i eat dinner
# Success: Juggling
# Success: Listen to music
# Nothing: Movie
# Success: Play games
# Nothing: Play guitar
# Success: Play musical chairs
# Nothing: Play on laptop
# Nothing: Play piano
# Nothing: Play with barbies
# Nothing: Playing video game
# Nothing: Playtime lunch with dolls
# Nothing: Practice own singing
# Nothing: Practice violin
# Success: Read book
# Success: Read magazine
# Success: Read news
# Success: Read newspaper
# Nothing: Read on sofa
# Success: Read yourself to sleep
# Success: Relax
# Success: Relax on sofa
# Nothing: Sing karaoke
# Nothing: Sing song
# Success: Social media  checks
# Nothing: Surf internet
# Success: Surf net
# Nothing: Tabletop game
# Nothing: Turn off tv
# Nothing: Turn on radio
# Nothing: Turn on tv
# Nothing: Turn on tv with remote
# Nothing: Watch  horror  movie
# Success: Watch movie
# Nothing: Watch tv
# Success: Watch youtube
# Nothing: Laugh
# Success: Read
# Success: Sew
# Success: Sit
# Nothing: Wait
# Nothing: Write
# Nothing: Add paper to printer
# Success: Admire art
# Nothing: Annoy your dog
# Nothing: Answer phone
# Nothing: Break table
# Nothing: Bring food
# Nothing: Bring me red cookbook
# Nothing: Build lego house
# Nothing: Card
# Success: Carry groceries to kitchen
# Nothing: Celebrate
# Nothing: Celebrate birthday with nice meal
# Nothing: Change tv channel
# Nothing: Clean eggs from our chickens
# Nothing: Close curtains
# Nothing: Close door
# Nothing: Close dresser drawer
# Nothing: Color
# Nothing: Come home
# Success: Come in and leave home
# Nothing: Compute
# Nothing: Cutting
# Nothing: De wrinkle sheet
# Nothing: Designing crafts with family
# Nothing: Do an art project
# Nothing: Do free-style dance routine
# Success: Draft home
# Success: Draw picture
# Success: Dry soap bottles
# Nothing: Enjoy view out window
# Success: Enter home
# Nothing: Fan magazines on coffee table
# Nothing: Feed daughter
# Nothing: Feed dog
# Nothing: Feed me
# Nothing: Find dictionary
# Nothing: Fix broken toys
# Success: Gaze out window
# Nothing: Get drink
# Success: Get glass of milk
# Success: Get glass of water
# Nothing: Get in way of guests trying to leave
# Nothing: Get out dish
# Nothing: Get some water
# Success: Get toilet paper
# Success: Getting  dresses
# Success: Give milk to cat
# Success: Grab some juice
# Success: Grab things
# Nothing: Hair
# Nothing: Hang car keys
# Success: Hang keys
# Nothing: Hang out
# Success: Hang up car keys
# Success: Hang up jacket
# Nothing: Hang with friends
# Nothing: Help organize files
# Nothing: Help with quiz shows
# Nothing: Hide
# Nothing: Keep cats inside while door is open
# Nothing: Lay down on floor and say im rug
# Nothing: Leave home
# Nothing: Let baby learn how to walk
# Nothing: Light candle
# Nothing: Lock door
# Nothing: Look at mirror
# Nothing: Look at painting
# Nothing: Look in refrigerator
# Success: Look out window
# Nothing: Make place cards
# Nothing: Make tutu
# Success: Open bathroom window
# Success: Open curtains
# Success: Open door
# Nothing: Open front door
# Success: Open window
# Success: Organize
# Nothing: Organize files
# Nothing: Pack lunch
# Nothing: Pet dog
# Success: Pick up
# Nothing: Pick up all trash
# Nothing: Pick up dishes
# Nothing: Pick up obvious trash
# Success: Pick up phone
# Nothing: Pick up spare change on dresser
# Success: Pick up toys
# Nothing: Play with toys
# Nothing: Plug in nightlight
# Nothing: Pop zit
# Nothing: Pour cup of coffee
# Nothing: Praying
# Nothing: Pretend tea
# Nothing: Pull up carpet
# Success: Push in desk chair
# Nothing: Push in dining room chair
# Nothing: Put away blankets
# Nothing: Put away clothes
# Success: Put away jackets
# Success: Put away keys
# Nothing: Put away shoes
# Success: Put away toys
# Success: Put clothes away
# Success: Put down bags
# Success: Put in chair
# Nothing: Put on purse put keys and lucky charms in pockets leave home
# Nothing: Put out flowers
# Success: Put umbrella away
# Success: Put up decoration
# Nothing: Put up feet
# Nothing: Put up jacket
# Nothing: Put up towel
# Nothing: Rain welcome
# Nothing: Raise blinds
# Nothing: Read text message
# Nothing: Receive credit card
# Nothing: Recycle items
# Nothing: Replace towel
# Nothing: Restock
# Nothing: Return from store
# Nothing: Return phone calls
# Nothing: Serve breakfast
# Nothing: Serve cookies
# Nothing: Serve food
# Nothing: Serve meal
# Success: Set mail on table
# Nothing: Set out some snacks for toddler
# Nothing: Set up tv
# Success: Settle in
# Nothing: Sew button
# Nothing: Shoe removal
# Nothing: Shop
# Success: Shredding
# Success: Shut front door
# Nothing: Shut off alarm
# Success: Sit in chair
# Nothing: Sit quietly
# Nothing: Sort mail
# Success: Spread table with appropriate supplies
# Nothing: Start computer
# Nothing: Straighten bookshelf
# Nothing: String green beans
# Nothing: Switch on lamp
# Nothing: Take coat
# Nothing: Take of outerwear
# Nothing: Teach them to make their bed
# Nothing: Throw away newspaper
# Success: Throw away paper
# Nothing: Throw shoes
# Nothing: Tidy
# Success: Try yourself off
# Nothing: Tummy time
# Success: Turking
# Success: Turn light off
# Success: Turn on computer
# Success: Turn on light
# Success: Turn on lights
# Success: Use laptop
# Nothing: Visit with friends while engaging in games
# Success: Walk through
# Success: Walk to room
# Nothing: Wash back
# Nothing: Wash dining table
# Success: Watch fly
# Nothing: Whine
# Success: Wipe down baseboards please
# Success: Wipe down counter
# Nothing: Wipe off shoes
# Nothing: Write book
# Nothing: Write in your diary
# Success: Write story
# Nothing: Stretch
# Nothing: Do yoga
# Nothing: Exercise
# Nothing: Physical therapy
# Nothing: Workout
# Nothing: Yoga
# Success: Answer door
# Nothing: Be able to talk to me about tv show im watching
# Nothing: Call client
# Nothing: Call family member with skype application
# Nothing: Call mother
# Nothing: Dance with kids
# Success: Entertain
# Nothing: Family meetings
# Nothing: Getting in way of guest trying to leave
# Nothing: Give children bath
# Success: Greet guests
# Success: Greet people
# Nothing: Hang with friend
# Success: Have conversation with boyfriend
# Nothing: Have party
# Nothing: Have quality family time
# Nothing: Have tea party
# Nothing: Help kids with homework
# Nothing: Ignore people
# Nothing: Keep cats out of room
# Nothing: Let bay learn how to walk
# Nothing: Make phone call
# Nothing: Massage
# Nothing: Meeting
# Nothing: Open door and great guests
# Success: Pet cat
# Nothing: Play fetch with dog
# Nothing: Read to child
# Nothing: Say goodbye
# Nothing: Say goodbye to guests leaving
# Nothing: Serve hors doeurves to entering guests at cocktail party
# Nothing: Speaking on headset in skype or some form of voip for business call
# Nothing: Spend family time playing games
# Success: Story reading time
# Nothing: Talk on phone
# Nothing: Talk to kids
# Nothing: Talk with friends
# Nothing: Talk with guest
# Nothing: Talk with your child about their day
# Nothing: Tell jokes
# Nothing: Text friend
# Success: Text friends while sitting on couch
# Nothing: Thanksgiving
# Nothing: Trick or treat
# Nothing: Tuck kids in bed
# Nothing: Visit
# Nothing: Visit neighbors
# Success: Wake kids up
# Nothing: Wave at people walking by through window
# Success: Answer emails
# Success: Browse internet
# Success: Check email
# Nothing: Check homework
# Nothing: Complete homework
# Nothing: Complete school work
# Nothing: Complete surveys on amazon turk
# Success: Computer work
# Nothing: Do homework
# Nothing: Do taxes
# Nothing: Do work
# Success: Do work on computer
# Nothing: Fax forms to doctor
# Success: File documents
# Nothing: File expense reports
# Nothing: Get mail ready
# Nothing: Grading papers
# Success: Homework
# Nothing: Mail signed letter to customer
# Nothing: Make several copies on printer
# Nothing: Manage documents
# Success: Manage emails
# Nothing: Order office suplies
# Nothing: Organise paperwork
# Nothing: Organize paperwork
# Success: Pay bills
# Nothing: Prepare for work
# Nothing: Prepare letter for mailing
# Nothing: Print documents
# Nothing: Print out document
# Success: Print out papers
# Nothing: Read paper
# Nothing: Research
# Nothing: Send  email
# Nothing: Sent email
# Nothing: Speaking on headset in skype or some form of voip for business call
# Success: Study
# Nothing: Study bible
# Success: Surf web for money legitimate making opportunities
# Nothing: Tax filing
# Nothing: Transcribe what i say
# Success: Type up document
# Nothing: Update address book
# Success: Use computer
# Success: Write an email
# Nothing: Write letter
# Success: Write report
# Nothing: Write research paper
# Nothing: Write research papers
# Nothing: Write school paper
# Nothing: Write thank you notes

# %%
for executable_activity in executable_activity_list:
    activity_list = executable_activity["results"]
    activity_name = executable_activity["activity_name"]
    activity_cnt = 0
    try:
        os.makedirs("graph_state_list/scene" + str(scene) + "/" + activity_name,exist_ok=True)
        for activity in activity_list:
            try:
                comm.reset(scene-1)
                comm.add_character('chars/Female2')
                success, g = comm.environment_graph();
                print(activity["file_name"])
                script = activity["list_of_steps"]
                preconds = add_preconds.get_preconds_script(script).printCondsJSON()
                g = check_programs.translate_graph_dict_nofile(g)
                info = check_programs.check_script(script, preconds, graph_path=None, inp_graph_dict=g)
                message, final_state, graph_state_list, graph_dict, id_mapping, info, helper, executed_script = info
                if message != "Script is executable":
                    print(message)
                    print("skipped")
                    continue
                # if delete randomly placced objects 
                graph_state_list = delete2000(graph_state_list)
                print(message)
                executed_program = []
                for x in executed_script:
                    executed_program.append("<char0> " + re.sub("\[\d+\]","",x.__str__()).strip())

                export(activity_name, graph_state_list, str(activity_cnt))
                activity_cnt += 1
            except Exception as e:
                print(e.args)
    except Exception as e:
        print(e.args)
# Out:
# results_intentions_march-13-18/file1027_2.txt
# Script is executable
# results_intentions_march-13-18/file269_2.txt
# Script is executable
# results_intentions_march-13-18/file597_1.txt
# Script is executable
# results_intentions_march-13-18/file144_2.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file854_2.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_upwork_kellensecond/split11_6.txt
# ('alarm_clock',)
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split80_3.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split1_3.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_turk_third/split7_1.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_turk_third/split82_2.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_text_rebuttal_specialparsed_programs_upwork_july/split22_2.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_upwork_july/split2_6.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split73_2.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_text_rebuttal_specialparsed_programs_upwork_kellensecond/split10_8.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_upwork_july/split6_5.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_turk_third/split82_3.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_text_rebuttal_specialparsed_programs_upwork_kellensecond/split6_10.txt
# Script is executable
# results_intentions_march-13-18/file97_1.txt
# Script is executable
# results_intentions_march-13-18/file628_2.txt
# Script is executable
# results_intentions_march-13-18/file662_1.txt
# Script is executable
# results_intentions_march-13-18/file488_2.txt
# Script is executable
# results_intentions_march-13-18/file291_1.txt
# Script is executable
# results_intentions_march-13-18/file814_1.txt
# Script is executable
# results_intentions_march-13-18/file510_1.txt
# Script is executable
# results_intentions_march-13-18/file609_1.txt
# Script is executable
# results_intentions_march-13-18/file907_2.txt
# Script is executable
# results_intentions_march-13-18/file72_2.txt
# Script is executable
# results_intentions_march-13-18/file540_2.txt
# Script is executable
# results_intentions_march-13-18/file24_1.txt
# Script is executable
# results_intentions_march-13-18/file17_1.txt
# Script is executable
# results_intentions_march-13-18/file317_2.txt
# Script is executable
# results_intentions_march-13-18/file810_2.txt
# Script is executable
# results_intentions_march-13-18/file532_1.txt
# Script is executable
# results_intentions_march-13-18/file641_2.txt
# Script is executable
# results_intentions_march-13-18/file573_1.txt
# Script is executable
# results_intentions_march-13-18/file878_2.txt
# Script is executable
# results_intentions_march-13-18/file842_1.txt
# Script is executable
# results_intentions_march-13-18/file171_2.txt
# Script is executable
# results_intentions_march-13-18/file286_2.txt
# Script is executable
# results_intentions_march-13-18/file657_2.txt
# Script is executable
# results_intentions_march-13-18/file136_2.txt
# Script is executable
# results_intentions_march-13-18/file1082_2.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file138_1.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file788_1.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split29_3.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_turk_third/split5_4.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_text_rebuttal_specialparsed_programs_turk_third/split97_1.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_turk_third/split82_4.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_text_rebuttal_specialparsed_programs_upwork_kellensecond/split9_4.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_turk_third/split114_3.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_upwork_july/split19_1.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_text_rebuttal_specialparsed_programs_turk_robot/split32_3.txt
# Script is executable
# results_intentions_march-13-18/file1085_1.txt
# Script is executable
# results_intentions_march-13-18/file755_2.txt
# Script is executable
# results_intentions_march-13-18/file478_2.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file141_1.txt
# Script is executable
# results_intentions_march-13-18/file893_2.txt
# Script is executable
# results_intentions_march-13-18/file955_2.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file550_2.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file101_1.txt
# Script is executable
# results_intentions_march-13-18/file714_2.txt
# Script is executable
# results_intentions_march-13-18/file392_2.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_text_rebuttal_specialparsed_programs_upwork_kellensecond/split7_2.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split1_2.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split29_2.txt
# ('coffe_maker',)
# results_intentions_march-13-18/file592_1.txt
# ('coffe_maker',)
# results_intentions_march-13-18/file800_2.txt
# ('coffe_maker',)
# results_intentions_march-13-18/file116_2.txt
# Script is executable
# results_intentions_march-13-18/file526_2.txt
# ('coffe_maker',)
# results_intentions_march-13-18/file250_2.txt
# ('coffe_maker',)
# results_intentions_march-13-18/file843_2.txt
# ('coffe_maker',)
# results_intentions_march-13-18/file71_1.txt
# ('coffe_maker',)
# results_intentions_march-13-18/file183_2.txt
# ('coffe_maker',)
# results_intentions_march-13-18/file281_2.txt
# ('coffe_maker',)
# results_intentions_march-13-18/file625_1.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file989_1.txt
# ('coffe_maker',)
# results_intentions_march-13-18/file217_1.txt
# ('coffe_maker',)
# results_intentions_march-13-18/file202_2.txt
# ('coffe_maker',)
# results_intentions_march-13-18/file51_1.txt
# ('coffe_maker',)
# results_intentions_march-13-18/file646_1.txt
# ('coffe_maker',)
# results_intentions_march-13-18/file310_2.txt
# ('coffe_maker',)
# results_intentions_march-13-18/file721_2.txt
# ('coffe_maker',)
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split87_1.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_turk_third/split2_2.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split127_2.txt
# ("check_putoff() missing 1 required positional argument: 'char_index'",)
# results_text_rebuttal_specialparsed_programs_turk_third/split95_4.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_upwork_kellensecond/split9_9.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_turk_robot/split97_2.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_upwork_kellensecond/split4_2.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_turk_robot/split14_2.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_turk_robot/split45_2.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_text_rebuttal_specialparsed_programs_turk_third/split75_3.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split31_2.txt
# ('washing_machine',)
# results_text_rebuttal_specialparsed_programs_turk_third/split92_4.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_upwork_july/split8_10.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_turk_robot/split90_3.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split38_3.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_turk_third/split27_2.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_text_rebuttal_specialparsed_programs_turk_robot/split11_1.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_text_rebuttal_specialparsed_programs_turk_third/split82_1.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_text_rebuttal_specialparsed_programs_turk_robot/split55_1.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_upwork_kellensecond/split6_8.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_upwork_kellensecond/split9_6.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_turk_third/split156_3.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split13_1.txt
# ("check_putoff() missing 1 required positional argument: 'char_index'",)
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split89_1.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_text_rebuttal_specialparsed_programs_turk_robot/split69_3.txt
# Script is executable
# results_intentions_march-13-18/file84_1.txt
# Script is executable
# results_intentions_march-13-18/file423_1.txt
# Script is executable
# results_intentions_march-13-18/file389_1.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file149_2.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_text_rebuttal_specialparsed_programs_turk_third/split19_2.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_turk_robot/split51_1.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split40_1.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_turk_third/split138_2.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_turk_third/split52_2.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_turk_third/split53_4.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split67_1.txt
# Script is executable
# results_intentions_march-13-18/file194_1.txt
# ('washing_machine',)
# results_intentions_march-13-18/file808_2.txt
# ('washing_machine',)
# results_intentions_march-13-18/file490_2.txt
# ('washing_machine',)
# results_intentions_march-13-18/file549_1.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file189_1.txt
# ('washing_machine',)
# results_intentions_march-13-18/file357_1.txt
# ('washing_machine',)
# results_intentions_march-13-18/file162_2.txt
# ('washing_machine',)
# results_intentions_march-13-18/file911_2.txt
# ('washing_machine',)
# results_intentions_march-13-18/file412_1.txt
# ('washing_machine',)
# results_intentions_march-13-18/file85_1.txt
# ('washing_machine',)
# results_intentions_march-13-18/file872_2.txt
# ('washing_machine',)
# results_intentions_march-13-18/file1045_2.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file702_2.txt
# Script is executable
# results_intentions_march-13-18/file78_1.txt
# ('washing_machine',)
# results_intentions_march-13-18/file389_2.txt
# ('washing_machine',)
# results_intentions_march-13-18/file1073_2.txt
# ('washing_machine',)
# results_intentions_march-13-18/file979_2.txt
# Script is executable
# results_intentions_march-13-18/file1021_2.txt
# ('washing_machine',)
# results_intentions_march-13-18/file448_2.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file643_1.txt
# ('washing_machine',)
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split62_2.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split103_1.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split150_1.txt
# Script is executable
# results_intentions_march-13-18/file31_1.txt
# Script is executable
# results_intentions_march-13-18/file345_2.txt
# Script is executable
# results_intentions_march-13-18/file961_1.txt
# Script is executable
# results_intentions_march-13-18/file695_2.txt
# Script is executable
# results_intentions_march-13-18/file988_1.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file395_2.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file165_1.txt
# Script is executable
# results_intentions_march-13-18/file390_1.txt
# Script is executable
# results_intentions_march-13-18/file746_1.txt
# Script is executable
# results_intentions_march-13-18/file955_1.txt
# Script is executable
# results_intentions_march-13-18/file349_1.txt
# Script is executable
# results_intentions_march-13-18/file183_1.txt
# Script is executable
# results_intentions_march-13-18/file856_1.txt
# Script is executable
# results_intentions_march-13-18/file403_2.txt
# Script is executable
# results_intentions_march-13-18/file911_1.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file1028_1.txt
# Script is executable
# results_intentions_march-13-18/file166_1.txt
# Script is executable
# results_intentions_march-13-18/file480_1.txt
# Script is executable
# results_intentions_march-13-18/file327_2.txt
# Script is executable
# results_intentions_march-13-18/file718_2.txt
# Script is executable
# results_intentions_march-13-18/file1021_1.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file477_1.txt
# Script is executable
# results_intentions_march-13-18/file783_1.txt
# Script is executable
# results_intentions_march-13-18/file44_1.txt
# Script is executable
# results_intentions_march-13-18/file487_1.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file117_2.txt
# Script is executable
# results_intentions_march-13-18/file201_1.txt
# Script is executable
# results_intentions_march-13-18/file989_2.txt
# Script is executable
# results_intentions_march-13-18/file517_2.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file847_1.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file463_1.txt
# Script is executable
# results_intentions_march-13-18/file931_2.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_turk_robot/split10_2.txt
# ('vacuum_cleaner',)
# results_text_rebuttal_specialparsed_programs_turk_robot/split17_2.txt
# ('vacuum_cleaner',)
# results_text_rebuttal_specialparsed_programs_turk_robot/split50_3.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_text_rebuttal_specialparsed_programs_turk_july/split7_2.txt
# ('vacuum_cleaner',)
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split68_3.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_turk_robot/split83_3.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_text_rebuttal_specialparsed_programs_turk_robot/split72_1.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_turk_third/split16_3.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_text_rebuttal_specialparsed_programs_turk_third/split92_2.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_turk_third/split72_4.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_turk_third/split108_3.txt
# Script is executable
# results_intentions_march-13-18/file367_1.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_text_rebuttal_specialparsed_programs_turk_robot/split49_2.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_text_rebuttal_specialparsed_programs_turk_third/split142_1.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_turk_robot/split36_1.txt
# ('vacuum_cleaner',)
# results_text_rebuttal_specialparsed_programs_turk_robot/split12_2.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split65_2.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split22_2.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_turk_robot/split67_2.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_text_rebuttal_specialparsed_programs_turk_robot/split68_2.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split34_1.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split120_1.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split2_2.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_turk_robot/split82_3.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_text_rebuttal_specialparsed_programs_turk_robot/split94_1.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_text_rebuttal_specialparsed_programs_turk_robot/split27_2.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_turk_third/split118_3.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_upwork_july/split2_8.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_turk_third/split3_1.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_text_rebuttal_specialparsed_programs_turk_robot/split16_2.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split132_1.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split21_2.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_turk_third/split39_1.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file233_2.txt
# Script is executable
# results_intentions_march-13-18/file618_2.txt
# Script is executable
# results_intentions_march-13-18/file300_2.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_turk_third/split110_2.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_turk_third/split109_3.txt
# ("check_putoff() missing 1 required positional argument: 'char_index'",)
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split61_1.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_turk_third/split67_1.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_turk_third/split113_1.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_turk_third/split4_2.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_upwork_july/split17_6.txt
# Script is executable
# results_intentions_march-13-18/file883_2.txt
# Script is executable
# results_intentions_march-13-18/file1035_2.txt
# Script is executable
# results_intentions_march-13-18/file323_2.txt
# Script is executable
# results_intentions_march-13-18/file360_2.txt
# Script is executable
# results_intentions_march-13-18/file478_1.txt
# Script is executable
# results_intentions_march-13-18/file496_1.txt
# Script is executable
# results_intentions_march-13-18/file430_2.txt
# Script is executable
# results_intentions_march-13-18/file1007_2.txt
# Script is executable
# results_intentions_march-13-18/file751_2.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_upwork_july/split4_7.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_turk_third/split96_2.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_turk_third/split117_2.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_turk_third/split13_2.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split136_2.txt
# ("check_putoff() missing 1 required positional argument: 'char_index'",)
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split115_1.txt
# ("check_putoff() missing 1 required positional argument: 'char_index'",)
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split156_3.txt
# ("check_putoff() missing 1 required positional argument: 'char_index'",)
# results_text_rebuttal_specialparsed_programs_turk_third/split44_1.txt
# ("check_putoff() missing 1 required positional argument: 'char_index'",)
# results_text_rebuttal_specialparsed_programs_turk_third/split70_1.txt
# ("check_putoff() missing 1 required positional argument: 'char_index'",)
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split90_3.txt
# ("check_putoff() missing 1 required positional argument: 'char_index'",)
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split154_3.txt
# ("check_putoff() missing 1 required positional argument: 'char_index'",)
# results_text_rebuttal_specialparsed_programs_turk_third/split17_1.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file848_2.txt
# Script is executable
# results_intentions_march-13-18/file187_1.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file502_2.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split26_3.txt
# ("check_putoff() missing 1 required positional argument: 'char_index'",)
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split91_3.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split145_3.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split69_3.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split73_3.txt
# Script is executable
# results_intentions_march-13-18/file499_1.txt
# Script is executable
# results_intentions_march-13-18/file132_2.txt
# Script is executable
# results_intentions_march-13-18/file671_2.txt
# Script is executable
# results_intentions_march-13-18/file311_2.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file154_2.txt
# Script is executable
# results_intentions_march-13-18/file574_2.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file607_1.txt
# Script is executable
# results_intentions_march-13-18/file813_2.txt
# Script is executable
# results_intentions_march-13-18/file1007_1.txt
# Script is executable
# results_intentions_march-13-18/file995_2.txt
# Script is executable
# results_intentions_march-13-18/file253_1.txt
# Script is executable
# results_intentions_march-13-18/file660_1.txt
# Script is executable
# results_intentions_march-13-18/file741_1.txt
# Script is executable
# results_intentions_march-13-18/file1061_1.txt
# Script is executable
# results_intentions_march-13-18/file766_2.txt
# Script is executable
# results_intentions_march-13-18/file320_2.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file640_1.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file1070_1.txt
# Script is executable
# results_intentions_march-13-18/file118_1.txt
# Script is executable
# results_intentions_march-13-18/file788_2.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_turk_third/split65_1.txt
# Script is executable
# results_intentions_march-13-18/file316_2.txt
# Script is executable
# results_intentions_march-13-18/file299_2.txt
# Script is executable
# results_intentions_march-13-18/file593_1.txt
# Script is executable
# results_intentions_march-13-18/file1046_1.txt
# Script is executable
# results_intentions_march-13-18/file246_1.txt
# Script is executable
# results_intentions_march-13-18/file67_2.txt
# Script is executable
# results_intentions_march-13-18/file1047_1.txt
# Script is executable
# results_intentions_march-13-18/file1043_2.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file151_1.txt
# Script is executable
# results_intentions_march-13-18/file374_2.txt
# Script is executable
# results_intentions_march-13-18/file263_2.txt
# Script is executable
# results_intentions_march-13-18/file446_1.txt
# Script is executable
# results_intentions_march-13-18/file294_2.txt
# Script is executable
# results_intentions_march-13-18/file7_1.txt
# Script is executable
# results_intentions_march-13-18/file590_1.txt
# Script is executable
# results_intentions_march-13-18/file613_1.txt
# Script is executable
# results_intentions_march-13-18/file384_1.txt
# Script is executable
# results_intentions_march-13-18/file145_1.txt
# Script is executable
# results_intentions_march-13-18/file385_1.txt
# Script is executable
# results_intentions_march-13-18/file799_2.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file486_1.txt
# Script is executable
# results_intentions_march-13-18/file465_2.txt
# Script is executable
# results_intentions_march-13-18/file394_1.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file698_1.txt
# Script is executable
# results_intentions_march-13-18/file875_2.txt
# Script is executable
# results_intentions_march-13-18/file393_1.txt
# Script is executable
# results_intentions_march-13-18/file410_1.txt
# Script is not executable, since <mouse> (300) already grabbed when executing "[GRAB] <mouse> (300) [14]"
# skipped
# results_intentions_march-13-18/file540_1.txt
# Script is executable
# results_intentions_march-13-18/file436_2.txt
# Script is executable
# results_intentions_march-13-18/file365_1.txt
# Script is executable
# results_intentions_march-13-18/file717_1.txt
# Script is executable
# results_intentions_march-13-18/file71_2.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_turk_robot/split22_2.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split74_1.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_turk_third/split73_3.txt
# Script is executable
# results_intentions_march-13-18/file501_1.txt
# ('cd_player',)
# results_intentions_march-13-18/file941_1.txt
# Script is executable
# results_intentions_march-13-18/file379_1.txt
# Script is executable
# results_intentions_march-13-18/file185_1.txt
# Script is executable
# results_intentions_march-13-18/file415_1.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file257_1.txt
# Script is executable
# results_intentions_march-13-18/file600_2.txt
# Script is executable
# results_intentions_march-13-18/file304_1.txt
# Script is executable
# results_intentions_march-13-18/file462_2.txt
# Script is executable
# results_intentions_march-13-18/file864_1.txt
# Script is executable
# results_intentions_march-13-18/file910_2.txt
# Script is executable
# results_intentions_march-13-18/file357_2.txt
# ('cd_player',)
# results_intentions_march-13-18/file599_1.txt
# ('cd_player',)
# results_intentions_march-13-18/file305_2.txt
# Script is executable
# results_intentions_march-13-18/file23_1.txt
# Script is executable
# results_intentions_march-13-18/file363_2.txt
# ('dvd_player',)
# results_intentions_march-13-18/file59_1.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file161_1.txt
# Script is executable
# results_intentions_march-13-18/file503_2.txt
# ('cd_player',)
# results_intentions_march-13-18/file113_1.txt
# ('cd_player',)
# results_intentions_march-13-18/file424_2.txt
# Script is executable
# results_intentions_march-13-18/file623_1.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file868_1.txt
# Script is executable
# results_intentions_march-13-18/file1074_2.txt
# Script is executable
# results_intentions_march-13-18/file441_1.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file267_2.txt
# ('cd_player',)
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split72_1.txt
# ('video_game_console',)
# results_text_rebuttal_specialparsed_programs_turk_third/split101_1.txt
# ('video_game_console',)
# results_text_rebuttal_specialparsed_programs_turk_third/split109_1.txt
# ('video_game_console',)
# results_text_rebuttal_specialparsed_programs_upwork_july/split13_2.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_turk_robot/split4_1.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_turk_third/split123_1.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_turk_third/split99_4.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_text_rebuttal_specialparsed_programs_turk_third/split53_3.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_turk_third/split51_1.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_upwork_kellensecond/split4_10.txt
# Script is executable
# results_intentions_march-13-18/file500_1.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file15_2.txt
# Script is executable
# results_intentions_march-13-18/file628_1.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file508_2.txt
# Script is executable
# results_intentions_march-13-18/file789_1.txt
# Script is executable
# results_intentions_march-13-18/file897_2.txt
# Script is executable
# results_intentions_march-13-18/file1087_1.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file247_2.txt
# Script is executable
# results_intentions_march-13-18/file684_1.txt
# Script is executable
# results_intentions_march-13-18/file221_2.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file821_1.txt
# Script is executable
# results_intentions_march-13-18/file662_2.txt
# Script is executable
# results_intentions_march-13-18/file196_1.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file651_2.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file192_1.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file241_2.txt
# Script is executable
# results_intentions_march-13-18/file1073_1.txt
# Script is executable
# results_intentions_march-13-18/file124_2.txt
# Script is executable
# results_intentions_march-13-18/file219_1.txt
# Script is executable
# results_intentions_march-13-18/file1065_2.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file193_1.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file693_2.txt
# Script is executable
# results_intentions_march-13-18/file1054_2.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file504_2.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file284_2.txt
# Script is executable
# results_intentions_march-13-18/file705_2.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_upwork_july/split11_5.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_upwork_july/split9_3.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_turk_robot/split64_2.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_upwork_kellensecond/split8_10.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_upwork_july/split15_4.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_turk_third/split3_3.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_text_rebuttal_specialparsed_programs_upwork_july/split22_9.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_text_rebuttal_specialparsed_programs_upwork_july/split1_8.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_text_rebuttal_specialparsed_programs_turk_third/split26_4.txt
# Script is executable
# results_intentions_march-13-18/file783_2.txt
# Script is executable
# results_intentions_march-13-18/file456_2.txt
# Script is executable
# results_intentions_march-13-18/file793_2.txt
# Script is executable
# results_intentions_march-13-18/file139_2.txt
# Script is not executable, since <character> (1) is not close to <pillow> (307) when executing "[FIND] <pillow> (307) [5]"
# skipped
# results_intentions_march-13-18/file604_1.txt
# Script is executable
# results_intentions_march-13-18/file623_2.txt
# Script is executable
# results_intentions_march-13-18/file1004_1.txt
# Script is executable
# results_intentions_march-13-18/file137_1.txt
# Script is executable
# results_intentions_march-13-18/file643_2.txt
# Script is executable
# results_intentions_march-13-18/file325_1.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file146_2.txt
# Script is executable
# results_intentions_march-13-18/file96_1.txt
# Script is executable
# results_intentions_march-13-18/file204_2.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file449_1.txt
# Script is executable
# results_intentions_march-13-18/file932_2.txt
# Script is executable
# results_intentions_march-13-18/file6_1.txt
# Script is executable
# results_intentions_march-13-18/file570_1.txt
# Script is executable
# results_intentions_march-13-18/file816_1.txt
# Script is executable
# results_intentions_march-13-18/file321_1.txt
# Script is executable
# results_intentions_march-13-18/file413_2.txt
# Script is executable
# results_intentions_march-13-18/file253_2.txt
# Script is executable
# results_intentions_march-13-18/file455_1.txt
# Script is executable
# results_intentions_march-13-18/file1028_2.txt
# Script is executable
# results_intentions_march-13-18/file762_2.txt
# Script is executable
# results_intentions_march-13-18/file124_1.txt
# Script is executable
# results_intentions_march-13-18/file318_2.txt
# Script is executable
# results_intentions_march-13-18/file418_2.txt
# Script is executable
# results_intentions_march-13-18/file1077_1.txt
# Script is executable
# results_intentions_march-13-18/file798_2.txt
# Script is executable
# results_intentions_march-13-18/file416_1.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_text_rebuttal_specialparsed_programs_turk_third/split123_4.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_turk_third/split2_4.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split130_3.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split17_3.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_turk_third/split112_1.txt
# ('remote_control',)
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split154_2.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_turk_third/split36_2.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_text_rebuttal_specialparsed_programs_turk_third/split91_3.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_turk_third/split43_4.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_upwork_kellensecond/split1_2.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_upwork_july/split7_2.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_turk_third/split108_1.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_turk_third/split41_2.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split19_1.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_upwork_kellensecond/split9_1.txt
# ("check_putoff() missing 1 required positional argument: 'char_index'",)
# results_text_rebuttal_specialparsed_programs_turk_third/split24_3.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split85_1.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_upwork_july/split11_4.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_turk_july/split3_2.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_text_rebuttal_specialparsed_programs_turk_july/split4_3.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split86_2.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_upwork_july/split13_1.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_upwork_july/split15_2.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_upwork_kellensecond/split1_11.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_turk_third/split105_4.txt
# Script is executable
# results_intentions_march-13-18/file303_1.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_upwork_kellensecond/split5_3.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_turk_robot/split10_1.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split83_3.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split65_3.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split9_2.txt
# ("check_putoff() missing 1 required positional argument: 'char_index'",)
# results_text_rebuttal_specialparsed_programs_turk_robot/split95_3.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_turk_third/split65_2.txt
# ("check_putoff() missing 1 required positional argument: 'char_index'",)
# results_text_rebuttal_specialparsed_programs_turk_third/split76_1.txt
# ("check_putoff() missing 1 required positional argument: 'char_index'",)
# results_text_rebuttal_specialparsed_programs_turk_third/split105_2.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_upwork_kellensecond/split7_3.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_turk_third/split140_1.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_turk_third/split49_3.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split36_1.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_turk_third/split36_3.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_text_rebuttal_specialparsed_programs_turk_third/split18_4.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file497_1.txt
# Script is executable
# results_intentions_march-13-18/file963_2.txt
# Script is executable
# results_intentions_march-13-18/file581_2.txt
# Script is executable
# results_intentions_march-13-18/file216_2.txt
# Script is executable
# results_intentions_march-13-18/file431_1.txt
# Script is executable
# results_intentions_march-13-18/file715_1.txt
# Script is executable
# results_intentions_march-13-18/file460_1.txt
# Script is executable
# results_intentions_march-13-18/file99_2.txt
# Script is executable
# results_intentions_march-13-18/file382_2.txt
# Script is executable
# results_intentions_march-13-18/file757_1.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file714_1.txt
# Script is executable
# results_intentions_march-13-18/file601_2.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file519_2.txt
# Script is executable
# results_intentions_march-13-18/file974_1.txt
# Script is executable
# results_intentions_march-13-18/file462_1.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file25_2.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file362_1.txt
# Script is executable
# results_intentions_march-13-18/file70_1.txt
# Script is executable
# results_intentions_march-13-18/file1071_2.txt
# Script is executable
# results_intentions_march-13-18/file244_1.txt
# Script is executable
# results_intentions_march-13-18/file348_1.txt
# Script is executable
# results_intentions_march-13-18/file241_1.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file223_1.txt
# Script is executable
# results_intentions_march-13-18/file532_2.txt
# Script is executable
# results_intentions_march-13-18/file209_1.txt
# Script is executable
# results_intentions_march-13-18/file973_1.txt
# Script is executable
# results_intentions_march-13-18/file1068_2.txt
# Script is executable
# results_intentions_march-13-18/file301_2.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file388_1.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file616_2.txt
# Script is executable
# results_intentions_march-13-18/file553_1.txt
# Script is executable
# results_intentions_march-13-18/file165_2.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file108_2.txt
# Script is executable
# results_intentions_march-13-18/file356_2.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_text_rebuttal_specialparsed_programs_turk_robot/split95_2.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_turk_robot/split6_3.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_turk_robot/split93_1.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split78_3.txt
# ("check_putoff() missing 1 required positional argument: 'char_index'",)
# results_text_rebuttal_specialparsed_programs_upwork_kellensecond/split2_1.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_turk_third/split102_3.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_text_rebuttal_specialparsed_programs_turk_third/split41_1.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_upwork_kellensecond/split4_1.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_text_rebuttal_specialparsed_programs_upwork_kellensecond/split7_4.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_turk_robot/split39_3.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_turk_third/split125_3.txt
# Script is not executable, since <centerpiece> (1000) already grabbed when executing "[GRAB] <centerpiece> (1000) [10]"
# skipped
# results_text_rebuttal_specialparsed_programs_turk_third/split74_1.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_text_rebuttal_specialparsed_programs_turk_third/split24_4.txt
# ("check_putoff() missing 1 required positional argument: 'char_index'",)
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split28_3.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_upwork_kellensecond/split7_11.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_upwork_kellensecond/split8_7.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_turk_third/split38_3.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_text_rebuttal_specialparsed_programs_upwork_kellensecond/split8_5.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_upwork_july/split17_7.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_turk_third/split69_3.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split12_2.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_turk_third/split56_4.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_turk_robot/split62_2.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_turk_third/split103_1.txt
# Script is executable
# results_intentions_march-13-18/file737_2.txt
# Script is executable
# results_intentions_march-13-18/file816_2.txt
# Script is executable
# results_intentions_march-13-18/file353_1.txt
# Script is executable
# results_intentions_march-13-18/file197_1.txt
# ('floor_lamp',)
# results_intentions_march-13-18/file461_2.txt
# Script is executable
# results_intentions_march-13-18/file585_1.txt
# ('floor_lamp',)
# results_intentions_march-13-18/file345_1.txt
# Script is executable
# results_intentions_march-13-18/file99_1.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file511_1.txt
# Script is executable
# results_intentions_march-13-18/file604_2.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file310_1.txt
# Script is executable
# results_intentions_march-13-18/file125_2.txt
# Script is executable
# results_intentions_march-13-18/file270_1.txt
# Script is executable
# results_intentions_march-13-18/file240_1.txt
# Script is executable
# results_intentions_march-13-18/file443_2.txt
# ('floor_lamp',)
# results_intentions_march-13-18/file150_2.txt
# Script is executable
# results_intentions_march-13-18/file85_2.txt
# Script is executable
# results_intentions_march-13-18/file825_2.txt
# Script is executable
# results_intentions_march-13-18/file160_1.txt
# Script is executable
# results_intentions_march-13-18/file753_1.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file381_2.txt
# Script is executable
# results_intentions_march-13-18/file627_1.txt
# Script is executable
# results_intentions_march-13-18/file409_1.txt
# Script is executable
# results_intentions_march-13-18/file835_2.txt
# Script is executable
# results_intentions_march-13-18/file705_1.txt
# Script is executable
# results_intentions_march-13-18/file392_1.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file885_2.txt
# Script is executable
# results_intentions_march-13-18/file302_2.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file874_2.txt
# Script is executable
# results_intentions_march-13-18/file232_2.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_upwork_kellensecond/split1_3.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_turk_robot/split65_3.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split82_2.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_upwork_kellensecond/split5_6.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_upwork_july/split5_4.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_turk_robot/split91_3.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_upwork_july/split14_8.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split155_1.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split63_3.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_turk_third/split39_4.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split115_3.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_turk_third/split24_1.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_turk_third/split14_2.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_turk_third/split117_1.txt
# Script is executable
# results_intentions_march-13-18/file836_2.txt
# Script is executable
# results_intentions_march-13-18/file1035_1.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file18_2.txt
# Script is executable
# results_intentions_march-13-18/file856_2.txt
# Script is executable
# results_intentions_march-13-18/file474_1.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file381_1.txt
# Script is executable
# results_intentions_march-13-18/file266_2.txt
# Script is executable
# results_intentions_march-13-18/file137_2.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file678_2.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# ...
# Script is executable
# results_intentions_march-13-18/file90_1.txt
# Script is executable
# results_intentions_march-13-18/file363_1.txt
# Script is executable
# results_intentions_march-13-18/file504_1.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file388_2.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file38_1.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file113_2.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file378_2.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file97_2.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file429_1.txt
# Script is executable
# results_intentions_march-13-18/file161_2.txt
# Script is executable
# results_intentions_march-13-18/file546_2.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file96_2.txt
# Script is executable
# results_intentions_march-13-18/file412_2.txt
# Script is executable
# results_intentions_march-13-18/file287_1.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file469_2.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file1063_2.txt
# Script is executable
# results_intentions_march-13-18/file203_2.txt
# Script is executable
# results_intentions_march-13-18/file734_1.txt
# Script is executable
# results_intentions_march-13-18/file322_2.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file612_1.txt
# Script is executable
# results_intentions_march-13-18/file501_2.txt
# Script is executable
# results_intentions_march-13-18/file988_2.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split160_1.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_turk_july/split4_1.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_turk_third/split11_2.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split98_3.txt
# Script is executable
# results_intentions_march-13-18/file316_2.txt
# Script is executable
# (17, 'File exists')
# results_intentions_march-13-18/file299_2.txt
# Script is executable
# (17, 'File exists')
# results_intentions_march-13-18/file593_1.txt
# Script is executable
# (17, 'File exists')
# results_intentions_march-13-18/file1046_1.txt
# Script is executable
# (17, 'File exists')
# results_intentions_march-13-18/file246_1.txt
# Script is executable
# (17, 'File exists')
# results_intentions_march-13-18/file67_2.txt
# Script is executable
# (17, 'File exists')
# results_intentions_march-13-18/file1047_1.txt
# Script is executable
# (17, 'File exists')
# results_intentions_march-13-18/file1043_2.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file151_1.txt
# Script is executable
# (17, 'File exists')
# results_intentions_march-13-18/file374_2.txt
# Script is executable
# (17, 'File exists')
# results_intentions_march-13-18/file263_2.txt
# Script is executable
# (17, 'File exists')
# results_intentions_march-13-18/file446_1.txt
# Script is executable
# (17, 'File exists')
# results_intentions_march-13-18/file294_2.txt
# Script is executable
# (17, 'File exists')
# results_intentions_march-13-18/file7_1.txt
# Script is executable
# (17, 'File exists')
# results_intentions_march-13-18/file590_1.txt
# Script is executable
# (17, 'File exists')
# results_intentions_march-13-18/file613_1.txt
# Script is executable
# (17, 'File exists')
# results_intentions_march-13-18/file384_1.txt
# Script is executable
# (17, 'File exists')
# results_intentions_march-13-18/file145_1.txt
# Script is executable
# (17, 'File exists')
# results_intentions_march-13-18/file385_1.txt
# Script is executable
# (17, 'File exists')
# results_intentions_march-13-18/file799_2.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file486_1.txt
# Script is executable
# (17, 'File exists')
# results_intentions_march-13-18/file465_2.txt
# Script is executable
# (17, 'File exists')
# results_intentions_march-13-18/file394_1.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file698_1.txt
# Script is executable
# (17, 'File exists')
# results_intentions_march-13-18/file875_2.txt
# Script is executable
# (17, 'File exists')
# results_intentions_march-13-18/file393_1.txt
# Script is executable
# (17, 'File exists')
# results_intentions_march-13-18/file410_1.txt
# Script is not executable, since <mouse> (300) already grabbed when executing "[GRAB] <mouse> (300) [14]"
# skipped
# results_intentions_march-13-18/file540_1.txt
# Script is executable
# (17, 'File exists')
# results_intentions_march-13-18/file436_2.txt
# Script is executable
# (17, 'File exists')
# results_intentions_march-13-18/file365_1.txt
# Script is executable
# (17, 'File exists')
# results_intentions_march-13-18/file717_1.txt
# Script is executable
# (17, 'File exists')
# results_intentions_march-13-18/file71_2.txt
# Script is executable
# (17, 'File exists')
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split71_2.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_text_rebuttal_specialparsed_programs_turk_third/split103_3.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_upwork_kellensecond/split1_8.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_upwork_kellensecond/split9_5.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split84_1.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split119_3.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split37_2.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_turk_third/split113_2.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_upwork_july/split10_4.txt
# Script is not executable, since <check> (1000) already grabbed when executing "[GRAB] <check> (1000) [10]"
# skipped
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split36_2.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_turk_third/split37_3.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_turk_third/split66_3.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_text_rebuttal_specialparsed_programs_upwork_july/split3_4.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_upwork_july/split1_7.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split143_3.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split127_3.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split140_2.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split15_2.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_upwork_july/split23_9.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split131_2.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split146_1.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split137_1.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split97_1.txt
# Script is executable
# results_intentions_march-13-18/file337_2.txt
# Script is executable
# results_intentions_march-13-18/file622_1.txt
# Script is executable
# results_intentions_march-13-18/file467_1.txt
# Script is executable
# results_intentions_march-13-18/file1040_2.txt
# Script is executable
# results_intentions_march-13-18/file986_2.txt
# Script is executable
# results_intentions_march-13-18/file709_2.txt
# Script is executable
# results_intentions_march-13-18/file327_1.txt
# Script is executable
# results_intentions_march-13-18/file543_2.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file122_2.txt
# Script is executable
# results_intentions_march-13-18/file200_1.txt
# Script is executable
# results_intentions_march-13-18/file22_1.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file450_2.txt
# Script is executable
# results_intentions_march-13-18/file808_1.txt
# Script is executable
# results_intentions_march-13-18/file592_2.txt
# Script is executable
# results_intentions_march-13-18/file185_2.txt
# Script is executable
# results_intentions_march-13-18/file115_2.txt
# Script is executable
# results_intentions_march-13-18/file749_2.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file590_2.txt
# Script is executable
# results_intentions_march-13-18/file587_2.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file75_2.txt
# Script is executable
# results_intentions_march-13-18/file481_2.txt
# Script is executable
# results_intentions_march-13-18/file681_2.txt
# Script is executable
# results_intentions_march-13-18/file996_2.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_turk_third/split19_1.txt
# Script is executable
# results_intentions_march-13-18/file381_1.txt
# Script is executable
# results_intentions_march-13-18/file451_1.txt
# Script is executable
# results_intentions_march-13-18/file429_1.txt
# Script is executable
# results_intentions_march-13-18/file287_1.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file220_2.txt
# Script is executable
# results_intentions_march-13-18/file363_1.txt
# Script is executable
# results_intentions_march-13-18/file575_2.txt
# Script is executable
# results_intentions_march-13-18/file412_2.txt
# Script is executable
# results_intentions_march-13-18/file1063_2.txt
# Script is executable
# results_intentions_march-13-18/file612_1.txt
# Script is executable
# results_intentions_march-13-18/file279_2.txt
# Script is executable
# results_intentions_march-13-18/file203_2.txt
# Script is executable
# results_intentions_march-13-18/file38_1.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file469_2.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file437_1.txt
# Script is executable
# results_intentions_march-13-18/file242_1.txt
# Script is executable
# results_intentions_march-13-18/file388_2.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file1035_1.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file856_2.txt
# Script is executable
# results_intentions_march-13-18/file502_1.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file297_1.txt
# Script is executable
# results_intentions_march-13-18/file137_2.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file113_2.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file519_1.txt
# Script is executable
# results_intentions_march-13-18/file12_2.txt
# Script is executable
# results_intentions_march-13-18/file479_2.txt
# Script is executable
# results_intentions_march-13-18/file292_1.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split5_3.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split114_3.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_turk_robot/split67_1.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split102_1.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split145_1.txt
# Script is executable
# results_intentions_march-13-18/file792_2.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file430_1.txt
# Script is executable
# results_intentions_march-13-18/file1003_2.txt
# Script is executable
# results_intentions_march-13-18/file749_2.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file884_1.txt
# Script is executable
# results_intentions_march-13-18/file986_2.txt
# Script is executable
# results_intentions_march-13-18/file182_1.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file87_2.txt
# Script is executable
# results_intentions_march-13-18/file1040_2.txt
# Script is executable
# results_intentions_march-13-18/file824_1.txt
# Script is executable
# results_intentions_march-13-18/file185_2.txt
# Script is executable
# results_intentions_march-13-18/file122_2.txt
# Script is executable
# results_intentions_march-13-18/file481_2.txt
# Script is executable
# results_intentions_march-13-18/file273_2.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file699_1.txt
# Script is executable
# results_intentions_march-13-18/file996_2.txt
# Script is executable
# results_intentions_march-13-18/file402_1.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_intentions_march-13-18/file115_2.txt
# Script is executable
# results_intentions_march-13-18/file349_2.txt
# Script is executable
# results_intentions_march-13-18/file407_1.txt
# Script is executable
# results_intentions_march-13-18/file622_1.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split140_2.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_turk_third/split66_3.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_text_rebuttal_specialparsed_programs_turk_third/split101_2.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_turk_third/split37_3.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_turk_third/split15_4.txt
# ('execute() takes 5 positional arguments but 6 were given',)
# results_text_rebuttal_specialparsed_programs_turk_third/split113_2.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split131_2.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split116_3.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split142_2.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_upwork_kellensecond/split11_10.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split38_1.txt
# Script is not executable, since <check> (1000) already grabbed when executing "[GRAB] <check> (1000) [10]"
# skipped
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split61_2.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split98_3.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_turk_third/split65_4.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_turk_third/split30_2.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_turk_third/split103_3.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_upwork_july/split23_9.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_upwork_july/split1_4.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_turk_third/split65_3.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_turk_robot/split49_1.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split119_3.txt
# Script is executable
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split83_1.txt
# Script is executable
# (17, 'File exists')
# results_text_rebuttal_specialparsed_programs_upworknturk_second/split84_1.txt
# Script is executable
